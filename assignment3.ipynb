# %%
#assignment 3-3rd question
num = int(input("Enter a number: "))

temp = num
rev = 0

while num > 0:
    digit = num % 10
    rev = rev * 10 + digit
    num = num // 10

if temp == rev:
    print("Palindrome Number")
else:
    print("Not a Palindrome Number")
# Out:
# Not a Palindrome Number

# %%
#assignment 3-2nd question
def add(a, b):
    return a + b

def sub(a, b):
    return a - b

def mul(a, b):
    return a * b

def div(a, b):
    return a / b


a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Addition =", add(a, b))
print("Subtraction =", sub(a, b))
print("Multiplication =", mul(a, b))
print("Division =", div(a, b))
# Out:
# Addition = 9
# Subtraction = -5
# Multiplication = 14
# Division = 0.2857142857142857

# %%
#assignment 3-1st question
# #sets:only have values but no keys so no duplicates allowed
s={"waj","son",True,1}
print(s)

#Set methods
#adding elements
s.add("apple")
print(s)

#union
s1={"Peas","tomato","Rabbit"}
s2={"Rabbit","Sqirrel"}
s3=s1.union(s2)
print(s3)

#intersection
s4=s1.intersection(s2)
print(s4)

#Difference
s5=s1.difference(s2)
print(s5)

#clearing of sets
s2.clear()
print(s2)
# Out:
# {True, 'waj', 'son'}
# {True, 'waj', 'apple', 'son'}
# {'Peas', 'Rabbit', 'Sqirrel', 'tomato'}
# {'Rabbit'}
# {'Peas', 'tomato'}
# set()

# %%
#assignment 3-1st question
# #Tuple: Ordered datatype used to store multiple items in a single variable.

#Iteration of Tuples
t=(10,'a',40,70,'11','KV')
l=len(t)
for i in range(l):
    print(t[i])
    #OR#
for i in t:
    print (i)
    
#Concatenation
t1=(0,1,2)
print(t+t1)

#nesting
t3=(t,t1)
print(t3)

#*Repetition
t2=('vk',)*7

#Slicing
print(t[1:])
print(t[::-1])
print(t[2:5:2])
#*print(t[-2:5:2])

#Deletion..of elements of tuple can't possible, thus we delete whole tuple
tup=(0,1)
del tup

#length of tuple
print(len(t))

#list to tuple
l=[1,2,3,4]
print(tuple(l))

#tuple methods
t=(10,20,30,40)
print(min(t))
print(max(t))
print(t.count(20))
print(t.index(40))
print(sum(t))
# Out:
# 10
# a
# 40
# 70
# 11
# KV
# 10
# a
# 40
# 70
# 11
# KV
# (10, 'a', 40, 70, '11', 'KV', 0, 1, 2)
# ((10, 'a', 40, 70, '11', 'KV'), (0, 1, 2))
# ('a', 40, 70, '11', 'KV')
# ('KV', '11', 70, 40, 'a', 10)
# (40, '11')
# 6
# (1, 2, 3, 4)
# 10
# 40
# 1
# 3
# 100

# %%
#assignment3-1st question
# #Dictionary: Store value in key value pair

d={1:'Vidhi', 2:'Soni'}
print(d,type(d))

#accessing elements
print(d[1])

#Nested Dictionary
di={'1':'python', '2':'Java', '3':'React', 'd2':{'pname':'abc','mrp':400}}
print(di['d2']['mrp'])

#add and delete elements
di[4]='cpp'
del(di['3'])
print(di)

#Dictionary methods
d2={'a':'Krishna','b':'Bhardwaj'}
d1=di.copy()
print(d1)
d1.items()
di.keys()
d1.values()
d.update(d2)
print(d)
di.pop('2')
di.popitem()
print(di)
# Out:
# {1: 'Vidhi', 2: 'Soni'} <class 'dict'>
# Vidhi
# 400
# {'1': 'python', '2': 'Java', 'd2': {'pname': 'abc', 'mrp': 400}, 4: 'cpp'}
# {'1': 'python', '2': 'Java', 'd2': {'pname': 'abc', 'mrp': 400}, 4: 'cpp'}
# {1: 'Vidhi', 2: 'Soni', 'a': 'Krishna', 'b': 'Bhardwaj'}
# {'1': 'python', 'd2': {'pname': 'abc', 'mrp': 400}}
