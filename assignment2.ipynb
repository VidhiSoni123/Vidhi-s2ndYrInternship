# %%
#1)
name = input("Enter Student Name: ")
cls = input("Enter Class: ")

m1 = float(input("Enter Marks of Subject 1: "))
m2 = float(input("Enter Marks of Subject 2: "))
m3 = float(input("Enter Marks of Subject 3: "))
m4 = float(input("Enter Marks of Subject 4: "))
m5 = float(input("Enter Marks of Subject 5: "))

total = m1 + m2 + m3 + m4 + m5
percentage = total / 5

print("\nRESULT")
print("Name :", name)
print("Class :", cls)
print("Total Marks :", total)
print("Percentage :", percentage, "%")
# Out:
# RESULT
# Name : VIdhi
# Class : 11
# Total Marks : 447.0
# Percentage : 89.4 %

# %%
#2)
str1 = input("Enter First String: ")
str2 = input("Enter Second String: ")

result = str1 + str2

print("Concatenated String =", result)

print("lower() =", result.lower())
print("upper() =", result.upper())
print("title() =", result.title())
print("swapcase() =", result.swapcase())
print("capitalize() =", result.capitalize())
print("casefold() =", result.casefold())

print("center() =", result.center(30, "*"))

print("count('a') =", result.count('a'))

print("endswith('a') =", result.endswith('a'))

print("find('a') =", result.find('a'))

print("isalnum() =", result.isalnum())
print("isdigit() =", result.isdigit())
print("isnumeric() =", result.isnumeric())
print("isspace() =", result.isspace())

print("replace() =", result.replace('a', '@'))
# Out:
# Concatenated String = Vidhi Krishna
# lower() = vidhi krishna
# upper() = VIDHI KRISHNA
# title() = Vidhi Krishna
# swapcase() = vIDHI kRISHNA
# capitalize() = Vidhi krishna
# casefold() = vidhi krishna
# center() = ********Vidhi Krishna*********
# count('a') = 1
# endswith('a') = True
# find('a') = 12
# isalnum() = False
# isdigit() = False
# isnumeric() = False
# isspace() = False
# replace() = Vidhi Krishn@

# %%
#3)
a = 10

print("Initial Value =", a)

a += 5
print("After += :", a)

a -= 3
print("After -= :", a)

a *= 2
print("After *= :", a)

a /= 4
print("After /= :", a)

a %= 3
print("After %= :", a)

a **= 2
print("After **= :", a)

a //= 2
print("After //= :", a)
# Out:
# Initial Value = 10
# After += : 15
# After -= : 12
# After *= : 24
# After /= : 6.0
# After %= : 0.0
# After **= : 0.0
# After //= : 0.0

# %%
#4)
name = input("Enter Student Name: ")
cls = input("Enter Class: ")

m1 = float(input("Enter Marks of Subject 1: "))
m2 = float(input("Enter Marks of Subject 2: "))
m3 = float(input("Enter Marks of Subject 3: "))
m4 = float(input("Enter Marks of Subject 4: "))
m5 = float(input("Enter Marks of Subject 5: "))

total = m1 + m2 + m3 + m4 + m5
percentage = total / 5

if percentage >= 60:
    grade = 'A'
elif percentage >= 50:
    grade = 'B'
elif percentage >= 40:
    grade = 'C'
elif percentage >= 33:
    grade = 'D'
else:
    grade = 'Fail'

print("\nRESULT")
print("Name :", name)
print("Class :", cls)
print("Total Marks :", total)
print("Percentage :", percentage, "%")
print("Grade :", grade)
# Out:
# RESULT
# Name : KRishna
# Class : 11
# Total Marks : 464.0
# Percentage : 92.8 %
# Grade : A
